# %%
import pandas as pd
import matplotlib.pyplot as plt

import sys
movies = pd.read_csv(r'E:\Komputer Dell - kopia\Dokumenty\Nauka programowania\Analiza Danych - Data Science z elementami AI\Wprowadzenie do Pythona\movies_subset.csv')

# %%
movies.head()
# Out:
#   imdb_title_id                                              title  \
# 0     tt7465704                                            7 Hosil
# 1    tt10443844  Psycho-Pass: Sinners of the System Case.1 Crim...
# 2     tt1537314                                 The Flying Machine
# 3     tt0306228                            Where's the Party Yaar?
# 4     tt0102812                                           Roujin Z
#
#                                       original_title  year date_published  \
# 0                                            7 Hosil  2017     2017-11-15
# 1  Psycho-Pass: Sinners of the System Case.1 Crim...  2019     2019-01-25
# 2                                 The Flying Machine  2011     2011-11-04
# 3                            Where's the Party Yaar?  2003     2004-05-28
# 4                                            Rôjin Z  1991     1991-09-14
#
#                           genre  duration                           country  \
# ...

# %%
len(set(movies['imdb_title_id'])) == len(movies['imdb_title_id'])
# Out:
# True

# %%
type( [1, 2] )
# Out:
# list

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21199 entries, 0 to 21198
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   imdb_title_id                21199 non-null  object
#  1   title                        21199 non-null  object
#  2   original_title               21199 non-null  object
#  3   year                         21199 non-null  int64
#  4   date_published               21199 non-null  object
#  5   genre                        21199 non-null  object
#  6   duration                     21199 non-null  int64
#  7   country                      21186 non-null  object
#  8   language                     21014 non-null  object
#  9   director                     21180 non-null  object
#  10  writer                       20784 non-null  object
#  11  production_company           20051 non-null  object
#  12  actors                       21183 non-null  object
# ...

# %%
movies.shape
"""
Podaje liczbę wierszy i liczbę kolumn
"""
# Out:
# (21199, 25)

# %%
movies.columns
"""
Zwraca wszystkie kolumny z tabeli
"""
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics', 'non-us',
#        'worlwide_gross_income_ccy', 'worlwide_gross_income_value'],
#       dtype='object')

# %%
for c in movies.columns :
    """
    Podaje po 10 przykładów z każdej kolumny
    """
    print()
    print( f"Przykładowe wartości z kolumny {c} :")
    print()
    print( movies[ c ].sample( n = 10))
# Out:
# Przykładowe wartości z kolumny imdb_title_id :
#
# 14860     tt6779396
# 1612      tt6128782
# 1866      tt0113420
# 14140     tt4443922
# 8654     tt10579992
# 2364      tt0110538
# 4752      tt0061418
# 14375     tt0092755
# 7015      tt0131636
# 15531     tt1646980
# Name: imdb_title_id, dtype: object
#
# Przykładowe wartości z kolumny title :
#
# 20138    La ragazza di madame Claude
# 2765                 Sesso in gabbia
# 8142                     The Nothing
# 14249                         Tarkan
# 9965                        Layla M.
# 3063                  A Outra Margem
# 15533                     Il vampiro
# 1377                  Lu Bian Ye Can
# 15586                        Streghe
# 11934     Duello al tempio maledetto
# Name: title, dtype: object
#
# Przykładowe wartości z kolumny original_title :
#
# 12330                              Himitsu no hanazono
# 18250                                        12 stulev
# 15042                                             Abby
# ...

# %% [markdown]
# Pytania analityczne

# %% [markdown]
# Ile filmów rocznie powstawało w latach 90-tych?

# %%
movies.head(2)
# Out:
#   imdb_title_id                                              title  \
# 0     tt7465704                                            7 Hosil
# 1    tt10443844  Psycho-Pass: Sinners of the System Case.1 Crim...
#
#                                       original_title  year date_published  \
# 0                                            7 Hosil  2017     2017-11-15
# 1  Psycho-Pass: Sinners of the System Case.1 Crim...  2019     2019-01-25
#
#                       genre  duration      country language  \
# 0          Comedy, Thriller       100  South Korea   Korean
# 1  Animation, Action, Crime        60        Japan  English
#
#             director  ... votes budget usa_gross_income worlwide_gross_income  \
# 0     Yong-seung Lee  ...   372    NaN              NaN             $ 2436110
# 1  Naoyoshi Shiotani  ...   315    NaN              NaN              $ 884371
#
#    metascore  reviews_from_users reviews_from_critics non-us  \
# ...

# %%
movies[ 'year' ].head(2)
# Out:
# 0    2017
# 1    2019
# Name: year, dtype: int64

# %%
movies[ 'year' ].unique()
# Out:
# array([2017, 2019, 2011, 2003, 1991, 1951, 2004, 2001, 2014, 1983, 2008,
#        1993, 2018, 1967, 2002, 1987, 1986, 1980, 1982, 2005, 1944, 1999,
#        1990, 1942, 2007, 1955, 2015, 1988, 1968, 1972, 2020, 1961, 1978,
#        1992, 2010, 2013, 1998, 1946, 1974, 2016, 1962, 1997, 1948, 1938,
#        1996, 2006, 1941, 1994, 1995, 1958, 2000, 1953, 1943, 1960, 1984,
#        1985, 1934, 2009, 1989, 1981, 1976, 1959, 1952, 2012, 1973, 1931,
#        1975, 1936, 1963, 1969, 1964, 1945, 1950, 1977, 1971, 1966, 1954,
#        1970, 1965, 1956, 1979, 1940, 1957, 1933, 1949, 1937, 1947, 1935,
#        1939, 1932])

# %%
#set( movies[ 'year' ]) Za pomocą setu możemy

# %%
movies[ 'year' ] > 1989
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 21194    False
# 21195     True
# 21196     True
# 21197     True
# 21198     True
# Name: year, Length: 21199, dtype: bool

# %%
movies_after89 = movies[ movies[ 'year' ] > 1989]
movies_after89['year'].min()
# Out:
# 1990

# %%
movies_before2000 = movies_after89 [ movies_after89[ 'year' ] < 2000]
movies_before2000['year'].max()
# Out:
# 1999

# %%
movies_nineties = movies[ ( movies[ 'year' ] > 1989) & ( movies_after89[ 'year' ] < 2000)]
movies_nineties['year'].min(), movies_nineties['year'].max()
# Out:
# (1990, 1999)

# %%
movies_nineties.head(2)
# Out:
#    imdb_title_id               title           original_title  year  \
# 4      tt0102812            Roujin Z                  Rôjin Z  1991
# 11     tt0107179  L'uomo in uniforme  I Love a Man in Uniform  1993
#
#    date_published                     genre  duration country  language  \
# 4      1991-09-14  Animation, Comedy, Drama        80   Japan  Japanese
# 11     1994-04-29           Drama, Thriller        99  Canada   English
#
#              director  ... votes budget usa_gross_income  \
# 4   Hiroyuki Kitakubo  ...  2190    NaN              NaN
# 11   David Wellington  ...   558    NaN          $ 93623
#
#    worlwide_gross_income  metascore  reviews_from_users reviews_from_critics  \
# 4                    NaN        NaN                 8.0                 22.0
# 11                   NaN        NaN                15.0                  7.0
#
#    non-us worlwide_gross_income_ccy  worlwide_gross_income_value
# 4       1                       NaN                          NaN
# ...

# %%
movies_nineties.groupby( 'year' ) [ 'imdb_title_id' ].count()
# Out:
# year
# 1990    196
# 1991    200
# 1992    198
# 1993    211
# 1994    218
# 1995    238
# 1996    243
# 1997    271
# 1998    291
# 1999    341
# Name: imdb_title_id, dtype: int64

# %%
movies_nineties.groupby( 'year' ) [ 'imdb_title_id' ].count().plot.bar()
plt.title('Liczba wyprodukowanych filmów w latach 90-tych', fontsize = 14, pad = 13)
plt.ylabel('Liczba wyprodukowanych filmów ', fontsize = 13, labelpad = 13)
plt.xlabel('Rok', fontsize = 13, labelpad = 13)
plt.show()

# %% [markdown]
# Ile filmów rocznie powstawało w latach 2010-tych?

# %%
movies_after2009 = movies [ movies[ 'year' ] > 2009]
movies_after2009[ 'year' ].min()
# Out:
# 2010

# %%
movies_before2020 = movies_after2009 [ movies_after2009[ 'year' ] < 2020 ]
movies_before2020[ 'year' ].max()
# Out:
# 2019

# %%
movies_2010s = movies [ ( movies[ 'year' ] > 2009 ) & ( movies_after2009[ 'year'] < 2020)]

movies_2010s.head(2)
# Out:
#   imdb_title_id                                              title  \
# 0     tt7465704                                            7 Hosil
# 1    tt10443844  Psycho-Pass: Sinners of the System Case.1 Crim...
#
#                                       original_title  year date_published  \
# 0                                            7 Hosil  2017     2017-11-15
# 1  Psycho-Pass: Sinners of the System Case.1 Crim...  2019     2019-01-25
#
#                       genre  duration      country language  \
# 0          Comedy, Thriller       100  South Korea   Korean
# 1  Animation, Action, Crime        60        Japan  English
#
#             director  ... votes budget usa_gross_income worlwide_gross_income  \
# 0     Yong-seung Lee  ...   372    NaN              NaN             $ 2436110
# 1  Naoyoshi Shiotani  ...   315    NaN              NaN              $ 884371
#
#    metascore  reviews_from_users reviews_from_critics non-us  \
# ...

# %%
statystyki_opisowe_roku = movies_2010s['year'].describe().round(2)
statystyki_opisowe_roku.loc[ [ 'min', 'max' ]]
# Out:
# min    2010.0
# max    2019.0
# Name: year, dtype: float64

# %%
movies_2010s.loc[1, [ 'original_title', 'year' ] ]
# Out:
# original_title    Psycho-Pass: Sinners of the System Case.1 Crim...
# year                                                           2019
# Name: 1, dtype: object

# %%
movies_2010.groupby( 'year') [ 'imdb_title_id']
movies_2010
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 movies_2010.groupby( 'year') [ 'imdb_title_id']
#       2 movies_2010
#
# NameError: name 'movies_2010' is not defined

# %%
movies_2010s.groupby( 'year' ) [ 'imdb_title_id' ].count().plot.bar(figsize = ( 13, 6 ))
plt.title('Liczba wyprodukowanych filmów w latach 2010-tych', fontsize = 14, pad = 13)
plt.ylabel('Liczba wyprodukowanych filmów ', fontsize = 13, labelpad = 13)
plt.xlabel('Rok', fontsize = 13, labelpad = 13)
plt.show()

# %% [markdown]
# Jak średnia długość amerykańskich filmów zmieniała się w XXI wieku?

# %%
slownik = { i : [i, i + 1] for i in range(3) }
slownik
# Out:
# {0: [0, 1], 1: [1, 2], 2: [2, 3]}

# %%
pd.DataFrame( slownik )
# Out:
#    0  1  2
# 0  0  1  2
# 1  1  2  3

# %%
tytuly = movies['title'].tolist()
tytuly[ :5 ]
# Out:
# ['7 Hosil',
#  'Psycho-Pass: Sinners of the System Case.1 Crime and Punishment',
#  'The Flying Machine',
#  "Where's the Party Yaar?",
#  'Roujin Z']

# %%
lata = movies['year'].tolist()
lata[ :5 ]
# Out:
# [2017, 2019, 2011, 2003, 1991]

# %%
movies_diction = {'title' : tytuly[ :10], 'year' : lata[ :10]}
movies_diction
# Out:
# {'title': ['7 Hosil',
#   'Psycho-Pass: Sinners of the System Case.1 Crime and Punishment',
#   'The Flying Machine',
#   "Where's the Party Yaar?",
#   'Roujin Z',
#   'La montagna dei sette falchi',
#   'Roma',
#   'Pearl Harbor',
#   'Jing Cheng 81 hao',
#   'Pukar'],
#  'year': [2017, 2019, 2011, 2003, 1991, 1951, 2004, 2001, 2014, 1983]}

# %%
for k, v in movies_diction.items() :
    if k == 'year' :
        for year in v :
            if year > 2003 :
                print( year )
# Out:
# 2017
# 2019
# 2011
# 2004
# 2014

# %%
movies_df = movies[ [ 'title', 'year' ] ].head(10)
movies_df
# Out:
#                                                title  year
# 0                                            7 Hosil  2017
# 1  Psycho-Pass: Sinners of the System Case.1 Crim...  2019
# 2                                 The Flying Machine  2011
# 3                            Where's the Party Yaar?  2003
# 4                                           Roujin Z  1991
# 5                       La montagna dei sette falchi  1951
# 6                                               Roma  2004
# 7                                       Pearl Harbor  2001
# 8                                  Jing Cheng 81 hao  2014
# 9                                              Pukar  1983

# %%
opis_roku = []

for y in movies_df['year'] :
    if y > 2000 :
        opis-roku.append(True)
    else : 
        opis_roku.append(False)

opis_roku
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 5
#       3 for y in movies_df['year'] :
#       4     if y > 2000 :
# ----> 5         opis-roku.append(True)
#       6     else :
#       7         opis_roku.append(False)
#
# NameError: name 'opis' is not defined

# %%
movies_df['xxi_wiek'] = [] # skrócona wersja[ True if y > 2000 else False for y in movies_df['year']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 movies_df['xxi_wiek'] = []
#
# File E:\Komputer Dell - kopia\Anaconda 3\Lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File E:\Komputer Dell - kopia\Anaconda 3\Lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
# ...

# %% [markdown]
# Jakie gatunki filmów są najczęstsze w Polsce?

# %%
movies[ 'country'] == 'Poland'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21194    False
# 21195    False
# 21196    False
# 21197    False
# 21198    False
# Name: country, Length: 21199, dtype: bool

# %%
polskie_filmy = movies[ movies['country'] == 'Poland']
polskie_filmy.head(2)
# Out:
#     imdb_title_id     title original_title  year date_published  genre  \
# 223     tt1517213       Las            Las  2009     2010-02-26  Drama
# 498     tt0480163  Komornik       Komornik  2005     2005-10-07  Drama
#
#      duration country language      director  ... votes budget  \
# 223        76  Poland   Polish  Piotr Dumala  ...   108    NaN
# 498       100  Poland   Polish   Feliks Falk  ...  1705    NaN
#
#     usa_gross_income worlwide_gross_income  metascore  reviews_from_users  \
# 223              NaN                   NaN        NaN                 NaN
# 498              NaN              $ 496454        NaN                 4.0
#
#     reviews_from_critics non-us worlwide_gross_income_ccy  \
# 223                  1.0      1                       NaN
# 498                  2.0      1                         $
#
#      worlwide_gross_income_value
# 223                          NaN
# 498                     496454.0
#
# [2 rows x 25 columns]

# %%
polskie_filmy['genre'].value_counts(dropna = False)
# Out:
# genre
# Drama                         38
# Comedy                        17
# Comedy, Drama                 13
# Comedy, Romance                9
# Drama, Romance                 6
# Comedy, Drama, Romance         4
# Action, Crime, Drama           4
# Thriller                       4
# Drama, War                     4
# Action, Comedy, Crime          3
# Drama, Thriller                3
# Action, Comedy                 3
# Crime, Drama                   3
# Drama, Comedy                  2
# Comedy, Crime                  2
# Action, Drama, History         2
# Crime, Drama, Thriller         2
# Action, Drama                  2
# Drama, Romance, War            2
# Crime, Thriller                2
# Romance                        2
# Romance, Comedy                1
# Drama, Thriller, War           1
# Drama, Mystery, Sci-Fi         1
# Drama, Crime, Thriller         1
# Drama, Music                   1
# Drama, Mystery, Romance        1
# Drama, Fantasy, Romance        1
# ...

# %%
polskie_filmy['genre'].head().str.upper()
# Out:
# 223                       DRAMA
# 498                       DRAMA
# 563                       DRAMA
# 1103     COMEDY, DRAMA, ROMANCE
# 1143    DRAMA, MYSTERY, ROMANCE
# Name: genre, dtype: object

# %%
osoba = "Jan Kowalski"
osoba.split()
# Out:
# ['Jan', 'Kowalski']

# %%
"Drama, Romance, Thriller".split(', ')
# Out:
# ['Drama', 'Romance', 'Thriller']

# %%
polskie_filmy = polskie_filmy.copy()
polskie_filmy [ ['genre1', 'genre2', 'genre3' ]] = polskie_filmy['genre'].str.split(', ', expand = True)
polskie_filmy [ ['original_title', 'genre', 'genre1', 'genre2', 'genre3']].head()
# Out:
#                                      original_title                    genre  \
# 223                                             Las                    Drama
# 498                                        Komornik                    Drama
# 563                      Kronika wypadków milosnych                    Drama
# 1103                               Glosniej od bomb   Comedy, Drama, Romance
# 1143  Lawa. Opowiesc o 'Dziadach' Adama Mickiewicza  Drama, Mystery, Romance
#
#       genre1   genre2   genre3
# 223    Drama     None     None
# 498    Drama     None     None
# 563    Drama     None     None
# 1103  Comedy    Drama  Romance
# 1143   Drama  Mystery  Romance

# %%
wszystie_genre_osobno = pd.concat([polskie_filmy['genre1'], polskie_filmy['genre2'], polskie_filmy['genre3']], axis = 0)
wszystie_genre_osobno.head(7)
# Out:
# 223      Drama
# 498      Drama
# 563      Drama
# 1103    Comedy
# 1143     Drama
# 1332     Drama
# 1429    Comedy
# dtype: object

# %%
len(wszystie_genre_osobno)
# Out:
# 498

# %%
len(polskie_filmy['genre1']) + len(polskie_filmy['genre2']) + len(polskie_filmy['genre3'])
# Out:
# 498

# %%
wszystie_genre_osobno.value_counts(dropna = False)
# Out:
# None         190
# Drama        105
# Comedy        63
# Romance       35
# Action        20
# Crime         18
# Thriller      17
# War           10
# Fantasy        6
# History        5
# Horror         4
# Adventure      4
# Mystery        4
# Family         3
# Sci-Fi         3
# Biography      3
# Music          3
# Musical        2
# Sport          2
# Western        1
# Name: count, dtype: int64

# %%
wszystie_genre_osobno.value_counts().head(7).plot.bar()
plt.ylabel('Liczba filmów')
plt.xlabel('Gatunek')
plt.ylabel('Liczba filmów wg gatunku w Polsce')
plt.show()

# %% [markdown]
# Który reżyser we Francji nakręcił najwięcej filmów?

# %%
french_movies = movies[ movies['country'] == 'France']
french_movies.head(3)
# Out:
#     imdb_title_id             title    original_title  year date_published  \
# 18      tt0080552  Cocktail Molotov  Cocktail Molotov  1980     1980-02-06
# 84      tt1459012     Crime d'amour     Crime d'amour  2010     2010-08-18
# 101     tt5078158      Juillet août      Juillet août  2016     2016-07-13
#
#                      genre  duration country                   language  \
# 18                   Drama       100  France                     French
# 84   Crime, Drama, Mystery       106  France  French, English, Japanese
# 101          Comedy, Drama        96  France                     French
#
#           director  ... votes budget usa_gross_income worlwide_gross_income  \
# 18     Diane Kurys  ...   106    NaN              NaN                   NaN
# 84   Alain Corneau  ...  4989    NaN         $ 539792             $ 3696522
# 101       Diastème  ...   186    NaN              NaN              $ 444064
#
#      metascore  reviews_from_users reviews_from_critics non-us  \
# ...

# %%
french_movies['director'].value_counts(dropna = False).head(10)
# Out:
# director
# Claude Lelouch       9
# André Téchiné        7
# Édouard Molinaro     7
# Julien Duvivier      6
# Jean-Pierre Mocky    6
# Marcel Pagnol        5
# Alexandre Arcady     5
# Jean Rollin          5
# Benoît Jacquot       5
# Gérard Krawczyk      5
# Name: count, dtype: int64

# %%
french_movies.groupby('director') ['genre'].value_counts()
# Out:
# director             genre
# Abd Al Malik         Drama                     1
# Abdellatif Kechiche  Comedy, Drama, Romance    1
#                      Drama                     1
# Adolfo Arrieta       Comedy                    1
# Agnès Jaoui          Comedy, Drama             1
#                                               ..
# Éléonore Faucher     Drama, Romance            1
# Éric Rohmer          Comedy, Drama, Romance    2
# Étienne Chatiliez    Comedy, Drama             1
#                      Comedy, Musical           1
# Étienne Faure        Drama, Romance            1
# Name: count, Length: 697, dtype: int64

# %%
french_movies.groupby('director') ['genre'].value_counts().index
# Out:
# MultiIndex([(       'Abd Al Malik',                  'Drama'),
#             ('Abdellatif Kechiche', 'Comedy, Drama, Romance'),
#             ('Abdellatif Kechiche',                  'Drama'),
#             (     'Adolfo Arrieta',                 'Comedy'),
#             (        'Agnès Jaoui',          'Comedy, Drama'),
#             (        'Agnès Varda',         'Drama, Romance'),
#             (    'Alain Berbérian',         'Comedy, Horror'),
#             (     'Alain Cavalier',                  'Drama'),
#             (     'Alain Cavalier',          'Comedy, Drama'),
#             (      'Alain Corneau',           'Crime, Drama'),
#             ...
#             (   'Édouard Molinaro',         'Drama, History'),
#             (   'Édouard Molinaro',               'Thriller'),
#             (       'Élise Girard',          'Comedy, Drama'),
#             (       'Élise Girard',                  'Drama'),
#             (   'Éléonore Faucher',                  'Drama'),
# ...

# %%
french_movies.groupby('director') ['genre'].value_counts().loc[ ('Claude Lelouch', slice(None)) ]
# Out:
# genre
# Drama                     3
# Comedy, Crime, Drama      1
# Comedy, Drama             1
# Comedy, Drama, Romance    1
# Comedy, Romance           1
# Crime, Drama, Romance     1
# Drama, History            1
# Name: count, dtype: int64

# %%
movies.head()
# Out:
#   imdb_title_id                                              title  \
# 0     tt7465704                                            7 Hosil
# 1    tt10443844  Psycho-Pass: Sinners of the System Case.1 Crim...
# 2     tt1537314                                 The Flying Machine
# 3     tt0306228                            Where's the Party Yaar?
# 4     tt0102812                                           Roujin Z
#
#                                       original_title  year date_published  \
# 0                                            7 Hosil  2017     2017-11-15
# 1  Psycho-Pass: Sinners of the System Case.1 Crim...  2019     2019-01-25
# 2                                 The Flying Machine  2011     2011-11-04
# 3                            Where's the Party Yaar?  2003     2004-05-28
# 4                                            Rôjin Z  1991     1991-09-14
#
#                           genre  duration                           country  \
# ...

# %%
kraje = movies['country'].tolist()
czy_us = [ ]

for k in kraje :
    if k == 'USA':
        czy_us.append( 1 )
    else:
        czy_us.append( 0 )

czy_us[ :5]
# Out:
# [0, 0, 0, 1, 0]

# %%
def classify_film(kraj) :

    if (kraj != 'USA') and ('USA' in kraj):
        return 'koprodukcja'
    elif kraj == 'USA' :
        return 'usa'
    else:
        return 'inny kraj'

# %%
movies['us'] = movies['country']#.apply(lambda x : 1 == 'USA' else 0)

# %%
def zwieksz_o_jeden( liczba ) :
    return liczba + 1

zwieksz_o_jeden( 2 )
# Out:
# 3

# %%
zwieksz_o_jeden = lambda liczba :liczba + 1
zwieksz_o_jeden( 2 )
# Out:
# 3

# %%
movies.groupby('us') ['imdb_title_id'].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 movies.groupby('us') ['imdb_title_id'].count()
#
# File E:\Komputer Dell - kopia\Anaconda 3\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %%
movies.groupby('us').size().div((len(movies) ).plot.barh()
plt.yticks([0, 1],['nie-amerykański', 'amerykański'])
plt.ylabel('')
plt.xlabel('Liczba filmów')
plt.title('Globalna proporcja filmów z USA w porównaniu do innych krajów')
plt.show()
# Out:
#   Cell In[123], line 1
#     movies.groupby('us').size().div((len(movies) ).plot.barh()
#                                    ^
# SyntaxError: '(' was never closed

# %% [markdown]
# Jaki był średni budżet us i non-us filmó w latach 2010-tych?

# %%
movies_2010s_new = movies_2010s = movies [ ( movies[ 'year' ] > 2009 ) & ( movies_after2009[ 'year'] < 2020)]
movies_2010s_new.head()
# Out:
#    imdb_title_id                                              title  \
# 0      tt7465704                                            7 Hosil
# 1     tt10443844  Psycho-Pass: Sinners of the System Case.1 Crim...
# 2      tt1537314                                 The Flying Machine
# 8      tt3816526                                  Jing Cheng 81 hao
# 12     tt6832388                                           The Dark
#
#                                        original_title  year date_published  \
# 0                                             7 Hosil  2017     2017-11-15
# 1   Psycho-Pass: Sinners of the System Case.1 Crim...  2019     2019-01-25
# 2                                  The Flying Machine  2011     2011-11-04
# 8                                   Jing Cheng 81 hao  2014     2014-07-18
# 12                                           The Dark  2018     2018-10-12
#
#                            genre  duration                           country  \
# ...

# %%
movies_2010s_new['budget'].head()
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 8     CNY 32000000
# 12             NaN
# Name: budget, dtype: object

# %%
movies_2010s_new['budget'].value_counts().sample(n = 12)
# Out:
# budget
# $ 4000000       30
# $ 15100000       1
# INR 25000000     4
# $ 2300000        2
# TRL 50000        1
# $ 23000000       2
# BRL 1500         1
# AUD 3400000      2
# $ 13500          1
# BRL 15000        1
# EUR 5500000      1
# ARS 7000000      1
# Name: count, dtype: int64

# %%
'EUR 5500000'.split()
# Out:
# ['EUR', '5500000']

# %%
movies_2010s_new = movies_2010s_new.copy()
movies_2010s_new[['waluta', 'budżet']] = movies_2010s_new['budget'].astype(str).str.split(expand = True)
movies_2010s_new[['title', 'budget', 'waluta', 'budżet']].head()
# Out:
#                                                 title        budget waluta  \
# 0                                             7 Hosil           NaN    nan
# 1   Psycho-Pass: Sinners of the System Case.1 Crim...           NaN    nan
# 2                                  The Flying Machine           NaN    nan
# 8                                   Jing Cheng 81 hao  CNY 32000000    CNY
# 12                                           The Dark           NaN    nan
#
#       budżet
# 0       None
# 1       None
# 2       None
# 8   32000000
# 12      None

# %%
movies_2010s_new['budżet'].unique()[ :10 ]
# Out:
# array([None, '32000000', '0', '5000000', '11000000', '500000', '10000000',
#        '15000000', '270000000', '38500000'], dtype=object)

# %%
movies_2010s_new['budżet'] = movies_2010s_new['budżet'].astype( float )
movies_2010s_new['budżet'].describe()
# Out:
# count    2.216000e+03
# mean     2.072464e+08
# std      2.827874e+09
# min      0.000000e+00
# 25%      7.620000e+05
# 50%      3.000000e+06
# 75%      1.800000e+07
# max      8.000000e+10
# Name: budżet, dtype: float64

# %%
movies_2010s_new.groupby('us') ['budżet'].mean() #wyniki zafałszowane przez różne waluty
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 movies_2010s_new.groupby('us') ['budżet'].mean()
#
# File E:\Komputer Dell - kopia\Anaconda 3\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %%
movies_2010s_new.groupby('us') ['waluta'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[141], line 1
# ----> 1 movies_2010s_new.groupby('us') ['waluta'].unique()
#
# File E:\Komputer Dell - kopia\Anaconda 3\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %%
filmy_non_us_z_waluta_usd =  [ (movies_2010s_new['waluta'] == '$') & (movies_2010s_new['us'] == 0) ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File E:\Komputer Dell - kopia\Anaconda 3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'us'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[142], line 1
# ...

# %%
movies_2010s_new_usd = movies_2010s_new[(movies_2010s_new['waluta'] == '$')
movies_2010s_new_usd.head()
# Out:
#   Cell In[143], line 1
#     movies_2010s_new_usd = movies_2010s_new[(movies_2010s_new['waluta'] == '$')
#                                            ^
# SyntaxError: '[' was never closed

# %%
movie_italy_france = movies[ movies['country'] == 'France' | (movies['country'] == 'Italy')]
movie_italy_france.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File E:\Komputer Dell - kopia\Anaconda 3\Lib\site-packages\pandas\core\ops\array_ops.py:362, in na_logical_op(x, y, op)
#     353 try:
#     354     # For exposition, write:
#     355     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     360     # Then Cases where this goes through without raising include:
#     361     #  (xint or xbool) and (yint or bool)
# --> 362     result = op(x, y)
#     363 except TypeError:
#
# File E:\Komputer Dell - kopia\Anaconda 3\Lib\site-packages\pandas\core\roperator.py:58, in ror_(left, right)
#      57 def ror_(left, right):
# ---> 58     return operator.or_(right, left)
#
# TypeError: ufunc 'bitwise_or' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# ...

# %%
movies_italy_france.shape()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 movies_italy_france.shape()
#
# NameError: name 'movies_italy_france' is not defined

# %%
wybrane_kolumny = ['original_title', 'year', 'director', 'avg_vote']
